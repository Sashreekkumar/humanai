# %% [markdown]
# # Spanish Transcritption

# %% [markdown]
# ## Installations

# %%
# !pip install python-Levenshtein
# Out:
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.12/dist-packages (0.27.3)
# Requirement already satisfied: Levenshtein==0.27.3 in /usr/local/lib/python3.12/dist-packages (from python-Levenshtein) (0.27.3)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from Levenshtein==0.27.3->python-Levenshtein) (3.14.3)

# %%
# !pip install pyannote.audio==3.1.1 --upgrade
# Out:
# Requirement already satisfied: pyannote.audio==3.1.1 in /usr/local/lib/python3.12/dist-packages (3.1.1)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (0.8.2)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (1.7.1)
# Requirement already satisfied: lightning>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (2.6.1)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (2.3.0)
# Requirement already satisfied: pyannote.core>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (6.0.1)
# Requirement already satisfied: pyannote.database>=5.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (6.1.1)
# Requirement already satisfied: pyannote.metrics>=3.2 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (4.0.0)
# Requirement already satisfied: pyannote.pipeline>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (4.0.0)
# Requirement already satisfied: pytorch-metric-learning>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (2.9.0)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (13.9.4)
# Requirement already satisfied: semver>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (3.0.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (0.13.1)
# Requirement already satisfied: speechbrain>=0.5.14 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (1.0.3)
# Requirement already satisfied: tensorboardX>=2.6 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (2.6.4)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (2.10.0+cu128)
# Requirement already satisfied: torch-audiomentations>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (0.12.0)
# Requirement already satisfied: torchaudio>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (2.10.0+cu128)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio==3.1.1) (1.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio==3.1.1) (2.4.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio==3.1.1) (4.15.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (0.24.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.1->pyannote.audio==3.1.1) (0.15.3)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.1->pyannote.audio==3.1.1) (2.6.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf<3.0,>=2.1->pyannote.audio==3.1.1) (4.9.3)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from pyannote.core>=5.0.0->pyannote.audio==3.1.1) (3.0.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.core>=5.0.0->pyannote.audio==3.1.1) (2.4.0)
# Requirement already satisfied: scikit-learn>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==3.1.1) (1.6.1)
# Requirement already satisfied: scipy>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==3.1.1) (1.16.3)
# Requirement already satisfied: optuna>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1) (4.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->pyannote.audio==3.1.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->pyannote.audio==3.1.1) (2.19.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->pyannote.audio==3.1.1) (2.0.0)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.12/dist-packages (from speechbrain>=0.5.14->pyannote.audio==3.1.1) (1.2.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from speechbrain>=0.5.14->pyannote.audio==3.1.1) (1.5.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from speechbrain>=0.5.14->pyannote.audio==3.1.1) (0.2.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX>=2.6->pyannote.audio==3.1.1) (5.29.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio==3.1.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->pyannote.audio==3.1.1) (1.4.3)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio==3.1.1) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio==3.1.1) (1.2.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio==3.1.1) (3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio==3.1.1) (0.1.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1) (2.0.48)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->pyannote.core>=5.0.0->pyannote.audio==3.1.1) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->pyannote.metrics>=3.2->pyannote.audio==3.1.1) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->pyannote.audio==3.1.1) (1.3.0)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.12/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1) (1.3)
# Requirement already satisfied: ruamel.yaml<0.19.0,>=0.17.28 in /usr/local/lib/python3.12/dist-packages (from hyperpyyaml->speechbrain>=0.5.14->pyannote.audio==3.1.1) (0.18.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->pyannote.audio==3.1.1) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.13.0->pyannote.audio==3.1.1) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1) (1.23.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1) (1.3.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->pyannote.core>=5.0.0->pyannote.audio==3.1.1) (1.17.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.15 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml<0.19.0,>=0.17.28->hyperpyyaml->speechbrain>=0.5.14->pyannote.audio==3.1.1) (0.2.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1) (3.3.2)

# %%
# !pip install faster_whisper
# Out:
# Requirement already satisfied: faster_whisper in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /usr/local/lib/python3.12/dist-packages (from faster_whisper) (4.7.1)
# Requirement already satisfied: huggingface-hub>=0.21 in /usr/local/lib/python3.12/dist-packages (from faster_whisper) (1.7.1)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster_whisper) (0.22.2)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.12/dist-packages (from faster_whisper) (1.24.4)
# Requirement already satisfied: av>=11 in /usr/local/lib/python3.12/dist-packages (from faster_whisper) (17.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from faster_whisper) (4.67.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster_whisper) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster_whisper) (2.4.3)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster_whisper) (6.0.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster_whisper) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster_whisper) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster_whisper) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster_whisper) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster_whisper) (26.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster_whisper) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster_whisper) (4.15.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster_whisper) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster_whisper) (5.29.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster_whisper) (1.14.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster_whisper) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster_whisper) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster_whisper) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster_whisper) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.21->faster_whisper) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2,>=1.14->faster_whisper) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.21->faster_whisper) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.21->faster_whisper) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.21->faster_whisper) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.21->faster_whisper) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.21->faster_whisper) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.21->faster_whisper) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.21->faster_whisper) (0.1.2)

# %%
# !pip install pyannote.audio
# Out:
# Requirement already satisfied: pyannote.audio in /usr/local/lib/python3.12/dist-packages (3.1.1)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (0.8.2)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (1.7.1)
# Requirement already satisfied: lightning>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (2.6.1)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (2.3.0)
# Requirement already satisfied: pyannote.core>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (6.0.1)
# Requirement already satisfied: pyannote.database>=5.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (6.1.1)
# Requirement already satisfied: pyannote.metrics>=3.2 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (4.0.0)
# Requirement already satisfied: pyannote.pipeline>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (4.0.0)
# Requirement already satisfied: pytorch-metric-learning>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (2.9.0)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (13.9.4)
# Requirement already satisfied: semver>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (3.0.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (0.13.1)
# Requirement already satisfied: speechbrain>=0.5.14 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (1.0.3)
# Requirement already satisfied: tensorboardX>=2.6 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (2.6.4)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (2.10.0+cu128)
# Requirement already satisfied: torch-audiomentations>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (0.12.0)
# Requirement already satisfied: torchaudio>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (2.10.0+cu128)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.audio) (1.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio) (2.4.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio) (4.15.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (0.24.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.1->pyannote.audio) (0.15.3)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.1->pyannote.audio) (2.6.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf<3.0,>=2.1->pyannote.audio) (4.9.3)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from pyannote.core>=5.0.0->pyannote.audio) (3.0.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.core>=5.0.0->pyannote.audio) (2.4.0)
# Requirement already satisfied: scikit-learn>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics>=3.2->pyannote.audio) (1.6.1)
# Requirement already satisfied: scipy>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics>=3.2->pyannote.audio) (1.16.3)
# Requirement already satisfied: optuna>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.pipeline>=3.0.1->pyannote.audio) (4.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->pyannote.audio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->pyannote.audio) (2.19.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->pyannote.audio) (2.0.0)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.12/dist-packages (from speechbrain>=0.5.14->pyannote.audio) (1.2.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from speechbrain>=0.5.14->pyannote.audio) (1.5.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from speechbrain>=0.5.14->pyannote.audio) (0.2.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX>=2.6->pyannote.audio) (5.29.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->pyannote.audio) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->pyannote.audio) (1.4.3)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (1.2.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio) (3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.13.0->pyannote.audio) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio) (0.1.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio) (2.0.48)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->pyannote.core>=5.0.0->pyannote.audio) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->pyannote.metrics>=3.2->pyannote.audio) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->pyannote.audio) (1.3.0)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.12/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio) (1.3)
# Requirement already satisfied: ruamel.yaml<0.19.0,>=0.17.28 in /usr/local/lib/python3.12/dist-packages (from hyperpyyaml->speechbrain>=0.5.14->pyannote.audio) (0.18.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->pyannote.audio) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.13.0->pyannote.audio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.13.0->pyannote.audio) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.13.0->pyannote.audio) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.23.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio) (1.3.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->pyannote.core>=5.0.0->pyannote.audio) (1.17.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.15 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml<0.19.0,>=0.17.28->hyperpyyaml->speechbrain>=0.5.14->pyannote.audio) (0.2.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=4.2.0->pyannote.pipeline>=3.0.1->pyannote.audio) (3.3.2)

# %%
# !pip install noisereduce
# Out:
# Requirement already satisfied: noisereduce in /usr/local/lib/python3.12/dist-packages (3.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from noisereduce) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from noisereduce) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from noisereduce) (2.4.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from noisereduce) (4.67.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from noisereduce) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.17.0)

# %%
# !pip install python-Levenshtein openpyxl -q

# %% [markdown]
# ## Imports

# %%
import numpy as np
import torch
import noisereduce as nr
import soundfile as sf
from faster_whisper import WhisperModel
from pydub import AudioSegment
import tempfile, os
import Levenshtein
import re
import openpyxl
from openpyxl.styles import Font, PatternFill, Alignment, Border, Side

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Preprocesssing

# %% [markdown]
# ### Load and Resample

# %%
def load_and_resample(path: str, target_sr: int = 16000):
    audio = AudioSegment.from_file(path)
    audio = audio.set_channels(1).set_frame_rate(target_sr)
    samples = np.array(audio.get_array_of_samples()).astype(np.float32)
    samples /= np.iinfo(audio.array_type).max   # normalize to [-1, 1]
    return samples, target_sr

# %% [markdown]
# ### VAD

# %%
def run_vad(samples: np.ndarray, sr: int, thr: float):
    model, utils = torch.hub.load(
        repo_or_dir="snakers4/silero-vad",
        model="silero_vad",
        force_reload=False
    )
    (get_speech_timestamps, _, read_audio, *_) = utils

    audio_tensor = torch.FloatTensor(samples)
    speech_timestamps = get_speech_timestamps(
        audio_tensor, model,
        sampling_rate=sr,
        threshold=thr,
        min_speech_duration_ms=250,
        min_silence_duration_ms=300,
    )
    segments = [(t["start"] / sr, t["end"] / sr) for t in speech_timestamps]
    print(f"[VAD] Found {len(segments)} speech segments")
    return segments

# %% [markdown]
# ### Add Padding

# %%
def add_padding(segments, sr, pad_ms=200):
    padded = []
    pad = int(pad_ms * sr / 1000)

    for s, e in segments:
        new_s = max(0, s - pad/sr)
        new_e = e + pad/sr
        padded.append((new_s, new_e))

    return padded

# %% [markdown]
# ### Concatenate only the VAD speech chunks

# %%
def extract_speech_audio(samples: np.ndarray, sr: int, segments):
    chunks = [samples[int(s * sr): int(e * sr)] for s, e in segments]
    speech_audio = np.concatenate(chunks) if chunks else samples
    print(f"[VAD] Kept {len(speech_audio)/sr:.1f}s of speech "
          f"from {len(samples)/sr:.1f}s total")
    return speech_audio

# %% [markdown]
# ### Noise Reduction

# %%
def reduce_noise(samples: np.ndarray, sr: int, pd: float):
    """Spectral noise reduction (noisereduce)."""
    denoised = nr.reduce_noise(y=samples, sr=sr, stationary=False, prop_decrease=pd)
    print("[Noise Reduction] Done")
    return denoised

# %% [markdown]
# ### Normalize Loudness

# %%
def normalize_audio(samples):
    max_val = np.max(np.abs(samples))
    if max_val > 0:
        samples = samples / max_val
    return samples

# %%
def remove_dc_offset(samples):
    return samples - np.mean(samples)

# %% [markdown]
# ### Merge Vad Segments before

# %%
def merge_vad_segments(segments, max_gap=0.5):
    merged = []
    current_start, current_end = segments[0]

    for s, e in segments[1:]:
        if s - current_end <= max_gap:
            current_end = e
        else:
            merged.append((current_start, current_end))
            current_start, current_end = s, e

    merged.append((current_start, current_end))
    return merged

# %% [markdown]
# ## Transcription

# %% [markdown]
# ### Transcribe

# %%
def transcribe(samples: np.ndarray, sr: int, speech_segments: list):
    model = WhisperModel("medium", device="cuda", compute_type="float16")

    results = []
    for i, (start, end) in enumerate(speech_segments):
        chunk = samples[int(start * sr): int(end * sr)]

        # Skip very short chunks
        if len(chunk) / sr < 0.5:
            continue

        segments, info = model.transcribe(
            chunk,
            language= "es",
            beam_size=5,
            vad_filter=False,
        )

        for seg in segments:
            results.append({
                "start": start + seg.start,   # offset by chunk start
                "end":   start + seg.end,
                "text":  seg.text.strip(),
                "lang":  info.language,
            })
            print(f"  [{start + seg.start:.1f}s → start + {seg.end:.1f}s] "
                  f"[{info.language}] {seg.text.strip()}")

    return results

# %% [markdown]
# ### Merging

# %%
def merge_until_target(results, target_count=30):
    current = results.copy()

    while len(current) > target_count:
        # Find shortest segment index
        lengths = [len(r["text"].split()) for r in current]
        idx = lengths.index(min(lengths))

        # If it's last element, merge with previous
        if idx == len(current) - 1:
            merge_idx = idx - 1
        else:
            merge_idx = idx

        # Merge current[merge_idx] and current[merge_idx + 1]
        merged = {
            "start": current[merge_idx]["start"],
            "end": current[merge_idx + 1]["end"],
            "text": current[merge_idx]["text"] + " " + current[merge_idx + 1]["text"]
        }

        # Replace the two with merged
        current = (
            current[:merge_idx] +
            [merged] +
            current[merge_idx + 2:]
        )

    return current

# %% [markdown]
# ## Post Processing

# %% [markdown]
# ### Stimulus List

# %%
STIMULI = [
    (1,  "Quiero cortarme el pelo"),
    (2,  "El libro está en la mesa"),
    (3,  "El carro lo tiene Pedro"),
    (4,  "El se ducha cada mañana"),
    (5,  "¿Qué dice usted que va a hacer hoy?"),
    (6,  "Dudo que sepa manejar muy bien"),
    (7,  "Las calles de esta ciudad son muy anchas"),
    (8,  "Puede que llueva mañana todo el día"),
    (9,  "Las casas son muy bonitas pero caras"),
    (10, "Me gustan las películas que acaban bien"),
    (11, "El chico con el que yo salgo es español"),
    (12, "Después de cenar me fui a dormir tranquilo"),
    (13, "Quiero una casa en la que vivan mis animales"),
    (14, "A nosotros nos fascinan las fiestas grandiosas"),
    (15, "Ella sólo bebe cerveza y no come nada"),
    (16, "Me gustaría que el precio de las casas bajara"),
    (17, "Cruza a la derecha y después sigue todo recto"),
    (18, "Ella ha terminado de pintar su apartamento"),
    (19, "Me gustaría que empezara a hacer más calor pronto"),
    (20, "El niño al que se le murió el gato está triste"),
    (21, "Una amiga mía cuida a los niños de mi vecino"),
    (22, "El gato que era negro fue perseguido por el perro"),
    (23, "Antes de poder salir él tiene que limpiar su cuarto"),
    (24, "La cantidad de personas que fuman ha disminuido"),
    (25, "Después de llegar a casa del trabajo tomé la cena"),
    (26, "El ladrón al que atrapó la policía era famoso"),
    (27, "Le pedí a un amigo que me ayudara con la tarea"),
    (28, "El examen no fue tan difícil como me habían dicho"),
    (29, "¿Serías tan amable de darme el libro que está en la mesa?"),
    (30, "Hay mucha gente que no toma nada para el desayuno"),
]


# ── Drop this into your pipeline after transcribe() ──────────────────────────

# %% [markdown]
# ### Normalizing Stimulus

# %%
def normalize(text):
    text = text.replace("<pause>", "")
    return re.sub(r'[^\w\s]', '', text.lower().strip())

# %% [markdown]
# ### Merging Nearby fragments

# %%
## merging 2 transcriptions if they have a gap of less than 2 seconds, and adding a <pause> token.
def merge_nearby_fragments(results, gap_threshold_s=2.0):
    if not results:
        return results

    merged = [results[0].copy()]
    for curr in results[1:]:
        prev = merged[-1]
        gap = curr["start"] - prev["end"]
        if gap <= gap_threshold_s:
            prev["end"]  = curr["end"]
            prev["text"] = prev["text"].rstrip() + " <pause> " + curr["text"].lstrip()  # ← only change
        else:
            merged.append(curr.copy())

    print(f"[Merge] {len(results)} segments → {len(merged)} after merging (gap ≤ {gap_threshold_s}s)")
    return merged

# %% [markdown]
# ### Matching ASR to Stimuli

# %%
def match_asr_to_stimuli(results, stimuli, max_dist=20):
    candidates = build_candidate_windows(results)

    used_spans = []
    matched = []

    for num, stim in stimuli:
        best_score = float('inf')
        best_text = "[not produced]"
        best_span = None

        for c in candidates:
            # avoid overlapping already-used segments
            overlap = any(not (c["end"] <= u[0] or c["start"] >= u[1]) for u in used_spans)
            if overlap:
                continue

            dist = Levenshtein.distance(
                normalize(c["text"]),
                normalize(stim)
            )

            if dist < best_score:
                best_score = dist
                best_text = c["text"]
                best_span = (c["start"], c["end"])

        if best_score <= max_dist:
            used_spans.append(best_span)
            transcription = best_text
        else:
            transcription = "[not produced]"

        matched.append({
            "sentence": num,
            "stimulus": stim,
            "transcription": transcription,
        })

        print(f"{num:>2}. [{stim}]")
        print(f"    → {transcription}  (dist={best_score})\n")

    return matched

# %% [markdown]
# ### SOmething idk what

# %%
def build_candidate_windows(results, max_window_size=3):
    candidates = []

    for i in range(len(results)):
        text = results[i]["text"]
        start = results[i]["start"]
        end = results[i]["end"]

        # window size 1, 2, 3
        for j in range(1, max_window_size + 1):
            if i + j > len(results):
                break

            if j > 1:
                next_seg = results[i + j - 1]
                text += " " + next_seg["text"]
                end = next_seg["end"]

            candidates.append({
                "start": start,
                "end": end,
                "text": text.strip()
            })

    print(f"[Windowing] Generated {len(candidates)} candidates")
    return candidates

# %% [markdown]
# ### Export

# %%
### export
def export_to_excel(matched, output_path):
    wb = openpyxl.Workbook()
    ws = wb.active
    ws.title = "Transcriptions"

    thin = Side(style="thin", color="CCCCCC")
    border = Border(left=thin, right=thin, top=thin, bottom=thin)

    # Header
    for col, label in enumerate(["Sentence", "Stimulus", "Transcription"], 1):
        cell = ws.cell(row=1, column=col, value=label)
        cell.font      = Font(bold=True, color="FFFFFF", name="Arial", size=11)
        cell.fill      = PatternFill("solid", start_color="4472C4")
        cell.alignment = Alignment(horizontal="center", vertical="center")
        cell.border    = border

    # Data rows
    for r in matched:
        ws.append([r["sentence"], r["stimulus"], r["transcription"]])
        for col in range(1, 4):
            cell = ws.cell(row=ws.max_row, column=col)
            cell.alignment = Alignment(wrap_text=True, vertical="top")
            cell.border    = border
            cell.font      = Font(name="Arial", size=11)

    ws.column_dimensions["A"].width = 10
    ws.column_dimensions["B"].width = 52
    ws.column_dimensions["C"].width = 52
    ws.row_dimensions[1].height     = 20

    wb.save(output_path)
    print(f"\n[Export] Saved → {output_path}")

# %% [markdown]
# ## Evaluation

# %%
def evaluate_results(matched):
    total = len(matched)
    not_produced = sum(1 for m in matched if m["transcription"] == "[not produced]")

    distances = []
    exact = 0

    for m in matched:
        if m["transcription"] == "[not produced]":
            continue

        dist = Levenshtein.distance(
            normalize(m["transcription"]),
            normalize(m["stimulus"])
        )

        distances.append(dist)

        if dist == 0:
            exact += 1

    avg_dist = sum(distances) / len(distances) if distances else 0

    print("\n─── EVALUATION ───")
    print(f"Total sentences: {total}")
    print(f"Matched: {total - not_produced}")
    print(f"Not produced: {not_produced}")
    print(f"Exact matches: {exact}")
    print(f"Average distance: {avg_dist:.2f}")

    return {
        "total": total,
        "matched": total - not_produced,
        "not_produced": not_produced,
        "exact": exact,
        "avg_distance": avg_dist
    }

# %% [markdown]
# ## Pipeline

# %% [markdown]
# ### Config

# %%
# ─── CONFIG ───────────────────────────────────────────────────────────────────
AUDIO_PATH     = "/content/drive/MyDrive/spanish/038010_EIT-2A.mp3"   # any format
TARGET_SR      = 16000              # Whisper expects 16kHz
HF_TOKEN       = ""         # for pyannote VAD
TRANSCRIBE_LANG = None                    # None = auto-detect; "es" = force Spanish
# ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### End-to-End

# %%
def run_eit_pipeline(audio_path, stimuli, output_path,
                     target_sr=16000,
                     vad_thr=0.35,
                     pad_ms=200,
                     max_gap=0.5,
                     use_denoise=False):

    print(f"\n================ PROCESSING: {audio_path} ================\n")

    # ─── LOAD ─────────────────────────────────────────────
    audio, sr = load_and_resample(audio_path, target_sr)

    # ─── BASIC CLEANING ───────────────────────────────────
    audio = remove_dc_offset(audio)
    audio = normalize_audio(audio)

    # ─── VAD ──────────────────────────────────────────────
    speech_segments = run_vad(audio, sr, thr=vad_thr)

    # ─── CONTEXT PRESERVATION ─────────────────────────────
    speech_segments = add_padding(speech_segments, sr, pad_ms=pad_ms)
    speech_segments = merge_vad_segments(speech_segments, max_gap=max_gap)

    # ─── OPTIONAL DENOISE ─────────────────────────────────
    if use_denoise:
        audio = reduce_noise(audio, sr, pd=0.5)

    # ─── TRANSCRIPTION ────────────────────────────────────
    results = transcribe(audio, sr, speech_segments)

    print("\n─── RAW SEGMENTS ───")
    for r in results:
        print(r["text"])

    # ─── MATCH + CORRECT ──────────────────────────────────
    print("\n─── MATCHING (WINDOWING + CORRECTION) ───")
    matched = match_asr_to_stimuli(results, stimuli)

    # ─── EXPORT ───────────────────────────────────────────
    export_to_excel(matched, output_path)

    # ─── EVALUATION ───────────────────────────────────────
    metrics = evaluate_results(matched)

    return {
        "results": results,
        "matched": matched,
        "metrics": metrics
    }

# %% [markdown]
# ## RUN

# %%
def summarize_all_runs(all_metrics):
    print("\n================ FINAL SUMMARY ================\n")

    header = f"{'File':<8} | {'Matched':<8} | {'NotProd':<8} | {'Exact':<8} | {'AvgDist':<8}"
    print(header)
    print("-" * len(header))

    total_files = len(all_metrics)

    sum_matched = 0
    sum_not_produced = 0
    sum_exact = 0
    sum_avg_dist = 0

    for i, m in enumerate(all_metrics):
        file_name = f"File_{i+1}"

        print(f"{file_name:<8} | {m['matched']:<8} | {m['not_produced']:<8} | {m['exact']:<8} | {m['avg_distance']:<8.2f}")

        sum_matched += m["matched"]
        sum_not_produced += m["not_produced"]
        sum_exact += m["exact"]
        sum_avg_dist += m["avg_distance"]

    # Averages
    avg_matched = sum_matched / total_files
    avg_not_produced = sum_not_produced / total_files
    avg_exact = sum_exact / total_files
    avg_distance = sum_avg_dist / total_files

    print("-" * len(header))
    print(f"{'AVG':<8} | {avg_matched:<8.2f} | {avg_not_produced:<8.2f} | {avg_exact:<8.2f} | {avg_distance:<8.2f}")

# %%
if __name__ == "__main__":
    AUDIO_FILES = [
        "/content/drive/MyDrive/spanish/038010_EIT-2A.mp3",
        "/content/drive/MyDrive/spanish/038011_EIT-1A.mp3",
        "/content/drive/MyDrive/spanish/038012_EIT-2A.mp3",
        "/content/drive/MyDrive/spanish/038015_EIT-1A.mp3",
    ]



    all_metrics = []

    for i, audio_path in enumerate(AUDIO_FILES):
        output_path = f"/content/drive/MyDrive/spanish/output_{i+1}.xlsx"

        result = run_eit_pipeline(audio_path, STIMULI, output_path)

        all_metrics.append(result["metrics"])
# Out:
# ================ PROCESSING: /content/drive/MyDrive/spanish/038010_EIT-2A.mp3 ================
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# [VAD] Found 53 speech segments
#   [73.9s → start + 2.0s] [es] nos fuimos al parque.
#   [81.4s → start + 2.0s] [es] La llamaré mañana.
#   [88.8s → start + 2.0s] [es] Puedes comprar carne en la tienda de butcher.
#   [97.2s → start + 2.8s] [es] Mi hermano recibió un nuevo computador.
#   [107.5s → start + 3.0s] [es] A veces toman a su papá para un paseo en el parque.
#   [118.9s → start + 3.0s] [es] Voy a jugar a la voleybal en el gimnasio que os he dicho.
#   [165.1s → start + 2.0s] [es] quiero cortarme el pelo
#   [172.4s → start + 2.0s] [es] El libro está en la mesa.
#   [179.8s → start + 2.0s] [es] El caro lo tiene pelo.
#   [187.9s → start + 2.0s] [es] ¡Ese duché cada mañana!
#   [197.0s → start + 2.8s] [es] ¿Qué dices ustedes que van a hacer hoy?
#   [206.1s → start + 3.0s] [es] Duro que sepa manejar muy bien.
#   [215.9s → start + 3.0s] [es] Las calles de esta ciudad son muy anchas.
#   [227.3s → start + 3.0s] [es] Puede que lleve mañana toda el día.
#   [238.6s → start + 5.0s] [es] Las casas son muy bonitas pero caras.
#   [250.2s → start + 3.0s] [es] Me gustan las películas que acaban bien.
#   [262.6s → start + 1.8s] [es] el chico que
#   [264.4s → start + 2.8s] [es] hago es español.
#   [274.5s → start + 4.0s] [es] Después de cenar, me fui a dormir tranquilo.
#   [286.4s → start + 4.0s] [es] Quiero una casa en la que viven animales.
#   [300.5s → start + 2.0s] [es] a nosotros
#   [313.7s → start + 5.0s] [es] Ella solo bebe cerveza y no come nada.
#   [327.1s → start + 2.0s] [es] Me gustaría...
#   [341.8s → start + 2.9s] [es] Curse a la derecha y después siga
#   [345.8s → start + 1.0s] [es] recto
#   [355.1s → start + 2.0s] [es] ya termina
#   [358.4s → start + 2.0s] [es] Pinta su apartamento.
#   [382.0s → start + 5.6s] [es] El niño a que se murió, el gato.
#   [388.3s → start + 1.0s] [es] Triste.
#   [396.0s → start + 2.0s] [es] Amiga mía
#   [398.8s → start + 2.6s] [es] Cuidado a los niños.
#   [410.1s → start + 3.0s] [es] el gato que era negro
#   [425.4s → start + 5.8s] [es] Antes de poder salir, tiene que limpiar su corto.
#   [441.3s → start + 3.0s] [es] la cantidad de personas que fuman.
#   [457.5s → start + 2.5s] [es] después de llegar a casa.
#   [473.0s → start + 3.6s] [es] El ladrón policía era famoso.
#   [488.4s → start + 4.0s] [es] Le pedí a un amigo que ayude a la trea.
#   [503.3s → start + 2.0s] [es] ¿Examen?
#   [505.3s → start + 4.0s] [es] Nooo...
#   [508.2s → start + 2.0s] [es] ¡Tan difícil!
#   [519.9s → start + 2.0s] [es] amable que está
#   [524.0s → start + 2.0s] [es] el libro que está en la mesa.
#   [533.7s → start + 7.0s] [es] hay mucha gente que no toma nada para desayuno.
#
# ─── RAW SEGMENTS ───
# nos fuimos al parque.
# La llamaré mañana.
# Puedes comprar carne en la tienda de butcher.
# Mi hermano recibió un nuevo computador.
# A veces toman a su papá para un paseo en el parque.
# Voy a jugar a la voleybal en el gimnasio que os he dicho.
# quiero cortarme el pelo
# El libro está en la mesa.
# El caro lo tiene pelo.
# ¡Ese duché cada mañana!
# ¿Qué dices ustedes que van a hacer hoy?
# Duro que sepa manejar muy bien.
# Las calles de esta ciudad son muy anchas.
# Puede que lleve mañana toda el día.
# Las casas son muy bonitas pero caras.
# Me gustan las películas que acaban bien.
# el chico que
# hago es español.
# Después de cenar, me fui a dormir tranquilo.
# Quiero una casa en la que viven animales.
# a nosotros
# Ella solo bebe cerveza y no come nada.
# Me gustaría...
# Curse a la derecha y después siga
# recto
# ya termina
# Pinta su apartamento.
# El niño a que se murió, el gato.
# Triste.
# Amiga mía
# Cuidado a los niños.
# el gato que era negro
# Antes de poder salir, tiene que limpiar su corto.
# la cantidad de personas que fuman.
# después de llegar a casa.
# El ladrón policía era famoso.
# Le pedí a un amigo que ayude a la trea.
# ¿Examen?
# Nooo...
# ¡Tan difícil!
# amable que está
# el libro que está en la mesa.
# hay mucha gente que no toma nada para desayuno.
#
# ─── MATCHING (WINDOWING + CORRECTION) ───
# [Windowing] Generated 126 candidates
#  1. [Quiero cortarme el pelo]
#     → quiero cortarme el pelo  (dist=0)
#
#  2. [El libro está en la mesa]
#     → El libro está en la mesa.  (dist=0)
#
#  3. [El carro lo tiene Pedro]
#     → El caro lo tiene pelo.  (dist=3)
#
#  4. [El se ducha cada mañana]
#     → ¡Ese duché cada mañana!  (dist=3)
#
#  5. [¿Qué dice usted que va a hacer hoy?]
#     → ¿Qué dices ustedes que van a hacer hoy?  (dist=4)
#
#  6. [Dudo que sepa manejar muy bien]
#     → Duro que sepa manejar muy bien.  (dist=1)
#
#  7. [Las calles de esta ciudad son muy anchas]
#     → Las calles de esta ciudad son muy anchas.  (dist=0)
#
#  8. [Puede que llueva mañana todo el día]
#     → Puede que lleve mañana toda el día.  (dist=3)
#
#  9. [Las casas son muy bonitas pero caras]
#     → Las casas son muy bonitas pero caras.  (dist=0)
#
# 10. [Me gustan las películas que acaban bien]
#     → Me gustan las películas que acaban bien.  (dist=0)
#
# 11. [El chico con el que yo salgo es español]
#     → el chico que hago es español.  (dist=12)
#
# 12. [Después de cenar me fui a dormir tranquilo]
#     → Después de cenar, me fui a dormir tranquilo.  (dist=0)
#
# 13. [Quiero una casa en la que vivan mis animales]
#     → Quiero una casa en la que viven animales.  (dist=5)
#
# 14. [A nosotros nos fascinan las fiestas grandiosas]
#     → [not produced]  (dist=33)
#
# 15. [Ella sólo bebe cerveza y no come nada]
#     → Ella solo bebe cerveza y no come nada.  (dist=1)
#
# 16. [Me gustaría que el precio de las casas bajara]
#     → [not produced]  (dist=24)
#
# 17. [Cruza a la derecha y después sigue todo recto]
#     → Curse a la derecha y después siga recto  (dist=11)
#
# 18. [Ella ha terminado de pintar su apartamento]
#     → ya termina Pinta su apartamento.  (dist=12)
#
# 19. [Me gustaría que empezara a hacer más calor pronto]
#     → [not produced]  (dist=33)
#
# 20. [El niño al que se le murió el gato está triste]
#     → El niño a que se murió, el gato. Triste.  (dist=9)
#
# 21. [Una amiga mía cuida a los niños de mi vecino]
#     → Amiga mía Cuidado a los niños.  (dist=19)
#
# 22. [El gato que era negro fue perseguido por el perro]
#     → [not produced]  (dist=28)
#
# 23. [Antes de poder salir él tiene que limpiar su cuarto]
#     → Antes de poder salir, tiene que limpiar su corto.  (dist=5)
#
# 24. [La cantidad de personas que fuman ha disminuido]
#     → la cantidad de personas que fuman.  (dist=14)
#
# 25. [Después de llegar a casa del trabajo tomé la cena]
#     → [not produced]  (dist=21)
#
# 26. [El ladrón al que atrapó la policía era famoso]
#     → El ladrón policía era famoso.  (dist=17)
#
# 27. [Le pedí a un amigo que me ayudara con la tarea]
#     → Le pedí a un amigo que ayude a la trea.  (dist=10)
#
# 28. [El examen no fue tan difícil como me habían dicho]
#     → [not produced]  (dist=28)
#
# 29. [¿Serías tan amable de darme el libro que está en la mesa?]
#     → ¡Tan difícil! amable que está el libro que está en la mesa.  (dist=18)
#
# 30. [Hay mucha gente que no toma nada para el desayuno]
#     → hay mucha gente que no toma nada para desayuno.  (dist=3)
#
#
# [Export] Saved → /content/drive/MyDrive/spanish/output_1.xlsx
#
# ─── EVALUATION ───
# Total sentences: 30
# Matched: 24
# Not produced: 6
# Exact matches: 6
# Average distance: 6.25
#
# ================ PROCESSING: /content/drive/MyDrive/spanish/038011_EIT-1A.mp3 ================
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# [VAD] Found 59 speech segments
#   [58.6s → start + 2.6s] [es] Nos... nos fuimos al parque.
#   [67.3s → start + 2.0s] [es] La llamaré mañana.
#   [74.5s → start + 2.0s] [es] Puedes comprar carne en la tienda de butcher.
#   [83.0s → start + 2.6s] [es] Mi hermano recibió un nuevo computador.
#   [91.9s → start + 4.4s] [es] Sometimes they take their dog sometimes they take their dog for a walk in the park.
#   [104.3s → start + 3.4s] [es] Vamos a jugar a la volea en el gimnasio que os he dicho.
#   [150.8s → start + 2.0s] [es] Quiero cortarme a pelo.
#   [158.0s → start + 2.0s] [es] El libro está en la mesa.
#   [165.4s → start + 2.0s] [es] El carro no tiene pelo.
#   [173.4s → start + 2.6s] [es] ¡Hasta la siguiente mañana!
#   [182.6s → start + 2.4s] [es] ¿Qué dice usted en qué base oe?
#   [191.6s → start + 3.0s] [es] tuve que manejar bien.
#   [201.5s → start + 5.0s] [es] las caes en salida muchos años.
#   [212.7s → start + 2.0s] [es] Puede que llevan mañana todos los días.
#   [223.9s → start + 4.0s] [es] Las casas son muy bonitas, pero caras.
#   [235.9s → start + 3.0s] [es] Me gustan las películas que acaban bien.
#   [247.8s → start + 2.6s] [es] El chico conectivo salgo.
#   [251.4s → start + 2.0s] [es] ¿Está bien?
#   [260.4s → start + 2.0s] [es] Después de cenar, me fui a...
#   [264.0s → start + 2.0s] [es] poner tranquilo.
#   [273.0s → start + 4.0s] [es] Quiero una casa que viven a mis animales.
#   [285.4s → start + 3.0s] [es] a nosotros que los vices.
#   [298.7s → start + 2.0s] [es] Y ya suena la cerveza y...
#   [301.7s → start + 1.2s] [es] ¡Como!
#   [312.7s → start + 5.0s] [es] Me gustaría los precios de los carros con lava.
#   [326.9s → start + 3.0s] [es] ¡Cursa a la derecha y siga!
#   [332.6s → start + 0.8s] [es] derecho.
#   [340.9s → start + 6.0s] [es] He terminado los apartamientos.
#   [353.3s → start + 2.6s] [es] Me gustaría las hacer...
#   [357.6s → start + 1.0s] [es] pronto.
#   [367.4s → start + 4.0s] [es] El niño que se murió al gato está triste.
#   [382.1s → start + 5.0s] [es] Una amiga viene cuidar a los niños a mi vecino.
#   [395.7s → start + 4.0s] [es] El gato era negro y...
#   [400.9s → start + 2.0s] [es] El perro.
#   [410.9s → start + 2.5s] [es] Antes de que salir
#   [416.1s → start + 3.3s] [es] ¿Puede cuarto?
#   [427.0s → start + 4.6s] [es] la cantidad de las personas fuman que en mi salido.
#   [441.9s → start + 2.0s] [es] Después de llegar a la casa...
#   [446.5s → start + 2.0s] [es] Fui a la cena.
#   [458.9s → start + 3.0s] [es] Perdón a la policía.
#   [464.5s → start + 2.0s] [es] eran famosos.
#   [473.4s → start + 5.0s] [es] le pedí a un amigo que ayudara con mi tarea.
#   [488.6s → start + 2.0s] [es] El examen no fue...
#   [504.5s → start + 3.0s] [es] Serias amable que lo están...
#   [519.2s → start + 3.0s] [es] hay mucha gente que no tomara el desayuno
#
# ─── RAW SEGMENTS ───
# Nos... nos fuimos al parque.
# La llamaré mañana.
# Puedes comprar carne en la tienda de butcher.
# Mi hermano recibió un nuevo computador.
# Sometimes they take their dog sometimes they take their dog for a walk in the park.
# Vamos a jugar a la volea en el gimnasio que os he dicho.
# Quiero cortarme a pelo.
# El libro está en la mesa.
# El carro no tiene pelo.
# ¡Hasta la siguiente mañana!
# ¿Qué dice usted en qué base oe?
# tuve que manejar bien.
# las caes en salida muchos años.
# Puede que llevan mañana todos los días.
# Las casas son muy bonitas, pero caras.
# Me gustan las películas que acaban bien.
# El chico conectivo salgo.
# ¿Está bien?
# Después de cenar, me fui a...
# poner tranquilo.
# Quiero una casa que viven a mis animales.
# a nosotros que los vices.
# Y ya suena la cerveza y...
# ¡Como!
# Me gustaría los precios de los carros con lava.
# ¡Cursa a la derecha y siga!
# derecho.
# He terminado los apartamientos.
# Me gustaría las hacer...
# pronto.
# El niño que se murió al gato está triste.
# Una amiga viene cuidar a los niños a mi vecino.
# El gato era negro y...
# El perro.
# Antes de que salir
# ¿Puede cuarto?
# la cantidad de las personas fuman que en mi salido.
# Después de llegar a la casa...
# Fui a la cena.
# Perdón a la policía.
# eran famosos.
# le pedí a un amigo que ayudara con mi tarea.
# El examen no fue...
# Serias amable que lo están...
# hay mucha gente que no tomara el desayuno
#
# ─── MATCHING (WINDOWING + CORRECTION) ───
# [Windowing] Generated 132 candidates
#  1. [Quiero cortarme el pelo]
#     → Quiero cortarme a pelo.  (dist=2)
#
#  2. [El libro está en la mesa]
#     → El libro está en la mesa.  (dist=0)
#
#  3. [El carro lo tiene Pedro]
#     → El carro no tiene pelo.  (dist=3)
#
#  4. [El se ducha cada mañana]
#     → La llamaré mañana.  (dist=12)
#
#  5. [¿Qué dice usted que va a hacer hoy?]
#     → ¿Qué dice usted en qué base oe?  (dist=12)
#
#  6. [Dudo que sepa manejar muy bien]
#     → tuve que manejar bien.  (dist=12)
#
#  7. [Las calles de esta ciudad son muy anchas]
#     → [not produced]  (dist=21)
#
#  8. [Puede que llueva mañana todo el día]
#     → Puede que llevan mañana todos los días.  (dist=7)
#
#  9. [Las casas son muy bonitas pero caras]
#     → Las casas son muy bonitas, pero caras.  (dist=0)
#
# 10. [Me gustan las películas que acaban bien]
#     → Me gustan las películas que acaban bien.  (dist=0)
#
# 11. [El chico con el que yo salgo es español]
#     → El chico conectivo salgo. ¿Está bien?  (dist=16)
#
# 12. [Después de cenar me fui a dormir tranquilo]
#     → Después de cenar, me fui a... poner tranquilo.  (dist=4)
#
# 13. [Quiero una casa en la que vivan mis animales]
#     → Quiero una casa que viven a mis animales.  (dist=9)
#
# 14. [A nosotros nos fascinan las fiestas grandiosas]
#     → [not produced]  (dist=29)
#
# 15. [Ella sólo bebe cerveza y no come nada]
#     → Y ya suena la cerveza y... ¡Como!  (dist=20)
#
# 16. [Me gustaría que el precio de las casas bajara]
#     → Me gustaría los precios de los carros con lava.  (dist=17)
#
# 17. [Cruza a la derecha y después sigue todo recto]
#     → ¡Cursa a la derecha y siga! derecho.  (dist=18)
#
# 18. [Ella ha terminado de pintar su apartamento]
#     → He terminado los apartamientos.  (dist=19)
#
# 19. [Me gustaría que empezara a hacer más calor pronto]
#     → [not produced]  (dist=23)
#
# 20. [El niño al que se le murió el gato está triste]
#     → El niño que se murió al gato está triste.  (dist=7)
#
# 21. [Una amiga mía cuida a los niños de mi vecino]
#     → Una amiga viene cuidar a los niños a mi vecino.  (dist=8)
#
# 22. [El gato que era negro fue perseguido por el perro]
#     → [not produced]  (dist=22)
#
# 23. [Antes de poder salir él tiene que limpiar su cuarto]
#     → [not produced]  (dist=25)
#
# 24. [La cantidad de personas que fuman ha disminuido]
#     → la cantidad de las personas fuman que en mi salido.  (dist=18)
#
# 25. [Después de llegar a casa del trabajo tomé la cena]
#     → Después de llegar a la casa... Fui a la cena.  (dist=17)
#
# 26. [El ladrón al que atrapó la policía era famoso]
#     → Perdón a la policía. eran famosos.  (dist=20)
#
# 27. [Le pedí a un amigo que me ayudara con la tarea]
#     → le pedí a un amigo que ayudara con mi tarea.  (dist=5)
#
# 28. [El examen no fue tan difícil como me habían dicho]
#     → [not produced]  (dist=26)
#
# 29. [¿Serías tan amable de darme el libro que está en la mesa?]
#     → [not produced]  (dist=32)
#
# 30. [Hay mucha gente que no toma nada para el desayuno]
#     → hay mucha gente que no tomara el desayuno  (dist=8)
#
#
# [Export] Saved → /content/drive/MyDrive/spanish/output_2.xlsx
#
# ─── EVALUATION ───
# Total sentences: 30
# Matched: 23
# Not produced: 7
# Exact matches: 3
# Average distance: 10.17
#
# ================ PROCESSING: /content/drive/MyDrive/spanish/038012-eit-2a_PXfLewZv.mp3 ================
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# [VAD] Found 60 speech segments
#   [2.5s → start + 1.0s] [es] Y WomenYou can buy it.
#   [3.6s → start + 3.2s] [es] You can buy me at a bus hotel.
#   [12.5s → start + 2.0s] [es] Mi hermano escribió un computador nuevo
#   [22.7s → start + 3.0s] [es] A veces toman al perro a la camina en el parque.
#   [33.8s → start + 3.0s] [es] Vamos a jugar volleyball en el gimnasio que os he dicho.
#   [80.6s → start + 2.0s] [es] quiero cortar
#   [87.8s → start + 2.0s] [es] El libro está a la mesa.
#   [95.3s → start + 2.0s] [es] El carro lo tiene a pelo.
#   [103.0s → start + 2.0s] [es] El seduce cada mañana.
#   [112.2s → start + 2.0s] [es] Quien hizo sé qué pasé hoy.
#   [121.2s → start + 4.0s] [es] duro, seca, lezard también
#   [131.6s → start + 2.0s] [es] la calle se siente
#   [135.0s → start + 3.0s] [es] Los callas.
#   [143.1s → start + 3.0s] [es] y el pueblo sigue la calle.
#   [153.9s → start + 2.5s] [es] Las casas son bonitas, pero caras.
#   [165.4s → start + 3.0s] [es] Me gustan las paléculas pecar bien.
#   [177.5s → start + 5.0s] [es] El chico es un bonalio es español.
#   [189.7s → start + 5.0s] [es] Después llegar, dormir...
#   [201.7s → start + 4.5s] [es] Quiero la casa esta a mis animales.
#   [214.9s → start + 5.0s] [es] A nosotros asesinabas, a los nosotros.
#   [228.6s → start + 6.0s] [es] es el conversino del...
#   [242.2s → start + 4.0s] [es] Me gustaría que los presos me estés.
#   [247.2s → start + 2.0s] [es] Ya...
#   [256.3s → start + 2.0s] [es] cruzar a la derecha
#   [259.3s → start + 1.0s] [es] Um...
#   [261.4s → start + 1.0s] [es] mmm
#   [270.3s → start + 6.0s] [es] Ella terminó el espaciatamiento.
#   [283.2s → start + 5.0s] [es] Me gustaría hacer pinatas esta...
#   [288.2s → start + 7.0s] [es] ...gustaría pronto.
#   [296.8s → start + 5.8s] [es] El niño, el niño Sirio Gato es tan muy triste.
#   [311.1s → start + 5.0s] [es] una amiga picado en mi vecino.
#   [325.4s → start + 7.0s] [es] el gato sin el negro y el perro
#   [341.0s → start + 3.0s] [es] que es el limpiar tus cuartos.
#   [356.4s → start + 5.7s] [es] la cantonalidad es afortunada personas
#   [371.8s → start + 6.0s] [es] Después de llegar a mi casa, voy a la cena.
#   [387.8s → start + 2.0s] [es] la policía era fórmula, así que...
#   [420.2s → start + 5.0s] [es] Tarea es la no difícil, pero derecha.
#   [433.7s → start + 6.0s] [es] ¿Qué está en la mesa de este libro?
#   [440.7s → start + 2.0s] [es] No, no, no, no, no, no.
#   [448.7s → start + 3.0s] [es] A mucha empleo, pero...
#   [456.0s → start + 1.0s] [es] mmm
#
# ─── RAW SEGMENTS ───
# Y WomenYou can buy it.
# You can buy me at a bus hotel.
# Mi hermano escribió un computador nuevo
# A veces toman al perro a la camina en el parque.
# Vamos a jugar volleyball en el gimnasio que os he dicho.
# quiero cortar
# El libro está a la mesa.
# El carro lo tiene a pelo.
# El seduce cada mañana.
# Quien hizo sé qué pasé hoy.
# duro, seca, lezard también
# la calle se siente
# Los callas.
# y el pueblo sigue la calle.
# Las casas son bonitas, pero caras.
# Me gustan las paléculas pecar bien.
# El chico es un bonalio es español.
# Después llegar, dormir...
# Quiero la casa esta a mis animales.
# A nosotros asesinabas, a los nosotros.
# es el conversino del...
# Me gustaría que los presos me estés.
# Ya...
# cruzar a la derecha
# Um...
# mmm
# Ella terminó el espaciatamiento.
# Me gustaría hacer pinatas esta...
# ...gustaría pronto.
# El niño, el niño Sirio Gato es tan muy triste.
# una amiga picado en mi vecino.
# el gato sin el negro y el perro
# que es el limpiar tus cuartos.
# la cantonalidad es afortunada personas
# Después de llegar a mi casa, voy a la cena.
# la policía era fórmula, así que...
# Tarea es la no difícil, pero derecha.
# ¿Qué está en la mesa de este libro?
# No, no, no, no, no, no.
# A mucha empleo, pero...
# mmm
#
# ─── MATCHING (WINDOWING + CORRECTION) ───
# [Windowing] Generated 120 candidates
#  1. [Quiero cortarme el pelo]
#     → quiero cortar  (dist=10)
#
#  2. [El libro está en la mesa]
#     → El libro está a la mesa.  (dist=2)
#
#  3. [El carro lo tiene Pedro]
#     → El carro lo tiene a pelo.  (dist=4)
#
#  4. [El se ducha cada mañana]
#     → El seduce cada mañana.  (dist=3)
#
#  5. [¿Qué dice usted que va a hacer hoy?]
#     → Quien hizo sé qué pasé hoy.  (dist=20)
#
#  6. [Dudo que sepa manejar muy bien]
#     → duro, seca, lezard también  (dist=16)
#
#  7. [Las calles de esta ciudad son muy anchas]
#     → [not produced]  (dist=21)
#
#  8. [Puede que llueva mañana todo el día]
#     → [not produced]  (dist=25)
#
#  9. [Las casas son muy bonitas pero caras]
#     → Las casas son bonitas, pero caras.  (dist=4)
#
# 10. [Me gustan las películas que acaban bien]
#     → Me gustan las paléculas pecar bien.  (dist=9)
#
# 11. [El chico con el que yo salgo es español]
#     → El chico es un bonalio es español.  (dist=11)
#
# 12. [Después de cenar me fui a dormir tranquilo]
#     → [not produced]  (dist=23)
#
# 13. [Quiero una casa en la que vivan mis animales]
#     → Quiero la casa esta a mis animales.  (dist=13)
#
# 14. [A nosotros nos fascinan las fiestas grandiosas]
#     → [not produced]  (dist=23)
#
# 15. [Ella sólo bebe cerveza y no come nada]
#     → [not produced]  (dist=25)
#
# 16. [Me gustaría que el precio de las casas bajara]
#     → Me gustaría que los presos me estés. Ya...  (dist=19)
#
# 17. [Cruza a la derecha y después sigue todo recto]
#     → [not produced]  (dist=25)
#
# 18. [Ella ha terminado de pintar su apartamento]
#     → [not produced]  (dist=21)
#
# 19. [Me gustaría que empezara a hacer más calor pronto]
#     → [not produced]  (dist=23)
#
# 20. [El niño al que se le murió el gato está triste]
#     → [not produced]  (dist=22)
#
# 21. [Una amiga mía cuida a los niños de mi vecino]
#     → una amiga picado en mi vecino.  (dist=20)
#
# 22. [El gato que era negro fue perseguido por el perro]
#     → [not produced]  (dist=23)
#
# 23. [Antes de poder salir él tiene que limpiar su cuarto]
#     → [not produced]  (dist=30)
#
# 24. [La cantidad de personas que fuman ha disminuido]
#     → [not produced]  (dist=30)
#
# 25. [Después de llegar a casa del trabajo tomé la cena]
#     → Después de llegar a mi casa, voy a la cena.  (dist=17)
#
# 26. [El ladrón al que atrapó la policía era famoso]
#     → [not produced]  (dist=31)
#
# 27. [Le pedí a un amigo que me ayudara con la tarea]
#     → [not produced]  (dist=32)
#
# 28. [El examen no fue tan difícil como me habían dicho]
#     → [not produced]  (dist=30)
#
# 29. [¿Serías tan amable de darme el libro que está en la mesa?]
#     → [not produced]  (dist=37)
#
# 30. [Hay mucha gente que no toma nada para el desayuno]
#     → [not produced]  (dist=33)
#
#
# [Export] Saved → /content/drive/MyDrive/spanish/output_3.xlsx
#
# ─── EVALUATION ───
# Total sentences: 30
# Matched: 13
# Not produced: 17
# Exact matches: 0
# Average distance: 11.38
#
# ================ PROCESSING: /content/drive/MyDrive/spanish/038015_EIT-1A.mp3 ================
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# [VAD] Found 48 speech segments
#   [55.4s → start + 2.0s] [es] Y nos fuimos al parque.
#   [64.8s → start + 2.0s] [es] La llamaré mañana.
#   [72.1s → start + 2.0s] [es] Puedes comprarme en la tienda de butchers
#   [80.8s → start + 2.6s] [es] Mi hermano recibió un nuevo computador.
#   [90.9s → start + 3.0s] [es] A veces toman a su papá para una caminada en el parque.
#   [101.9s → start + 3.0s] [es] Vamos a jugar volleyball en el gimnasio que os he dicho.
#   [148.5s → start + 2.0s] [es] Quiero cortarme el pelo.
#   [155.8s → start + 2.0s] [es] El libro está en la mesa.
#   [163.1s → start + 2.0s] [es] El carro no tiene pelo.
#   [171.3s → start + 2.0s] [es] El seducha cada mañana.
#   [180.4s → start + 2.0s] [es] que dice a ustedes que vas a Arroyo.
#   [189.2s → start + 2.0s] [es] ¿Tuvo que se permanecer bien?
#   [199.2s → start + 3.8s] [es] Las calles de esta ciudad son muy anchas.
#   [210.2s → start + 2.0s] [es] Puede que lleve mañana toro al día.
#   [221.6s → start + 3.0s] [es] Las casas son muy bonitas, pero caras.
#   [233.3s → start + 2.8s] [es] Me gustan las películas que acaban bien.
#   [245.5s → start + 3.0s] [es] El chico con esto algo es español.
#   [257.6s → start + 3.6s] [es] Después de cenar, me fui a dormir tranquilo.
#   [269.6s → start + 3.0s] [es] Quiero una casa en que le vivan mis animales.
#   [283.1s → start + 3.3s] [es] A nosotros nos fascinan las fiestas grandes.
#   [296.9s → start + 3.6s] [es] Ella solo bebe cerveza y come nada.
#   [310.3s → start + 3.0s] [es] Me gustaría las precios cajas.
#   [324.2s → start + 3.4s] [es] Cruza a la derecha y sigue el toro resto.
#   [338.0s → start + 3.6s] [es] Ellos han terminado de suspender su apartamento.
#   [351.5s → start + 4.0s] [es] Me gustaría hacer más calor pronto.
#   [365.0s → start + 1.0s] [es] El Niño
#   [367.2s → start + 3.0s] [es] que se murió el gato y está triste.
#   [378.9s → start + 3.0s] [es] Una amiga me cuidaron a los niños.
#   [393.6s → start + 3.5s] [es] El gato negro fuera perseguido por el perro.
#   [408.7s → start + 2.0s] [es] Ante esta tiendesa leer.
#   [411.7s → start + 2.0s] [es] Limpiar el cuarto
#   [424.1s → start + 5.2s] [es] la cantidad de personas que fuman es...
#   [439.6s → start + 5.5s] [es] Después de llegar a la casa, después del trabajo, comen la cena.
#   [455.3s → start + 5.0s] [es] El ladrón que atrapó con la policía era famoso.
#   [471.0s → start + 5.0s] [es] Le pedí a un amigo que me ayudara en la tarea.
#   [487.7s → start + 4.0s] [es] El trabajo no fue difícil, me ha dicho.
#   [501.8s → start + 3.0s] [es] Serías tan amable, puede darme...
#   [505.4s → start + 2.0s] [es] el libro en el mesa.
#   [516.6s → start + 3.8s] [es] Hay mucha gente que no toma nada para el desayuno.
#
# ─── RAW SEGMENTS ───
# Y nos fuimos al parque.
# La llamaré mañana.
# Puedes comprarme en la tienda de butchers
# Mi hermano recibió un nuevo computador.
# A veces toman a su papá para una caminada en el parque.
# Vamos a jugar volleyball en el gimnasio que os he dicho.
# Quiero cortarme el pelo.
# El libro está en la mesa.
# El carro no tiene pelo.
# El seducha cada mañana.
# que dice a ustedes que vas a Arroyo.
# ¿Tuvo que se permanecer bien?
# Las calles de esta ciudad son muy anchas.
# Puede que lleve mañana toro al día.
# Las casas son muy bonitas, pero caras.
# Me gustan las películas que acaban bien.
# El chico con esto algo es español.
# Después de cenar, me fui a dormir tranquilo.
# Quiero una casa en que le vivan mis animales.
# A nosotros nos fascinan las fiestas grandes.
# Ella solo bebe cerveza y come nada.
# Me gustaría las precios cajas.
# Cruza a la derecha y sigue el toro resto.
# Ellos han terminado de suspender su apartamento.
# Me gustaría hacer más calor pronto.
# El Niño
# que se murió el gato y está triste.
# Una amiga me cuidaron a los niños.
# El gato negro fuera perseguido por el perro.
# Ante esta tiendesa leer.
# Limpiar el cuarto
# la cantidad de personas que fuman es...
# Después de llegar a la casa, después del trabajo, comen la cena.
# El ladrón que atrapó con la policía era famoso.
# Le pedí a un amigo que me ayudara en la tarea.
# El trabajo no fue difícil, me ha dicho.
# Serías tan amable, puede darme...
# el libro en el mesa.
# Hay mucha gente que no toma nada para el desayuno.
#
# ─── MATCHING (WINDOWING + CORRECTION) ───
# [Windowing] Generated 114 candidates
#  1. [Quiero cortarme el pelo]
#     → Quiero cortarme el pelo.  (dist=0)
#
#  2. [El libro está en la mesa]
#     → El libro está en la mesa.  (dist=0)
#
#  3. [El carro lo tiene Pedro]
#     → El carro no tiene pelo.  (dist=3)
#
#  4. [El se ducha cada mañana]
#     → El seducha cada mañana.  (dist=1)
#
#  5. [¿Qué dice usted que va a hacer hoy?]
#     → que dice a ustedes que vas a Arroyo.  (dist=12)
#
#  6. [Dudo que sepa manejar muy bien]
#     → ¿Tuvo que se permanecer bien?  (dist=11)
#
#  7. [Las calles de esta ciudad son muy anchas]
#     → Las calles de esta ciudad son muy anchas.  (dist=0)
#
#  8. [Puede que llueva mañana todo el día]
#     → Puede que lleve mañana toro al día.  (dist=4)
#
#  9. [Las casas son muy bonitas pero caras]
#     → Las casas son muy bonitas, pero caras.  (dist=0)
#
# 10. [Me gustan las películas que acaban bien]
#     → Me gustan las películas que acaban bien.  (dist=0)
#
# 11. [El chico con el que yo salgo es español]
#     → El chico con esto algo es español.  (dist=8)
#
# 12. [Después de cenar me fui a dormir tranquilo]
#     → Después de cenar, me fui a dormir tranquilo.  (dist=0)
#
# 13. [Quiero una casa en la que vivan mis animales]
#     → Quiero una casa en que le vivan mis animales.  (dist=5)
#
# 14. [A nosotros nos fascinan las fiestas grandiosas]
#     → A nosotros nos fascinan las fiestas grandes.  (dist=4)
#
# 15. [Ella sólo bebe cerveza y no come nada]
#     → Ella solo bebe cerveza y come nada.  (dist=4)
#
# 16. [Me gustaría que el precio de las casas bajara]
#     → Me gustaría las precios cajas.  (dist=20)
#
# 17. [Cruza a la derecha y después sigue todo recto]
#     → Cruza a la derecha y sigue el toro resto.  (dist=13)
#
# 18. [Ella ha terminado de pintar su apartamento]
#     → Ellos han terminado de suspender su apartamento.  (dist=9)
#
# 19. [Me gustaría que empezara a hacer más calor pronto]
#     → Me gustaría hacer más calor pronto.  (dist=15)
#
# 20. [El niño al que se le murió el gato está triste]
#     → El Niño que se murió el gato y está triste.  (dist=8)
#
# 21. [Una amiga mía cuida a los niños de mi vecino]
#     → Una amiga me cuidaron a los niños.  (dist=18)
#
# 22. [El gato que era negro fue perseguido por el perro]
#     → El gato negro fuera perseguido por el perro.  (dist=10)
#
# 23. [Antes de poder salir él tiene que limpiar su cuarto]
#     → [not produced]  (dist=24)
#
# 24. [La cantidad de personas que fuman ha disminuido]
#     → la cantidad de personas que fuman es...  (dist=12)
#
# 25. [Después de llegar a casa del trabajo tomé la cena]
#     → Después de llegar a la casa, después del trabajo, comen la cena.  (dist=14)
#
# 26. [El ladrón al que atrapó la policía era famoso]
#     → El ladrón que atrapó con la policía era famoso.  (dist=7)
#
# 27. [Le pedí a un amigo que me ayudara con la tarea]
#     → Le pedí a un amigo que me ayudara en la tarea.  (dist=2)
#
# 28. [El examen no fue tan difícil como me habían dicho]
#     → El trabajo no fue difícil, me ha dicho.  (dist=19)
#
# 29. [¿Serías tan amable de darme el libro que está en la mesa?]
#     → Serías tan amable, puede darme... el libro en el mesa.  (dist=13)
#
# 30. [Hay mucha gente que no toma nada para el desayuno]
#     → Hay mucha gente que no toma nada para el desayuno.  (dist=0)
#
#
# [Export] Saved → /content/drive/MyDrive/spanish/output_4.xlsx
#
# ─── EVALUATION ───
# Total sentences: 30
# Matched: 29
# Not produced: 1
# Exact matches: 7
# Average distance: 7.31

# %%
summarize_all_runs(all_metrics)
# Out:
# ================ FINAL SUMMARY ================
#
# File     | Matched  | NotProd  | Exact    | AvgDist
# ----------------------------------------------------
# File_1   | 24       | 6        | 6        | 6.25
# File_2   | 23       | 7        | 3        | 10.17
# File_3   | 13       | 17       | 0        | 11.38
# File_4   | 29       | 1        | 7        | 7.31
# ----------------------------------------------------
# AVG      | 22.25    | 7.75     | 4.00     | 8.78
